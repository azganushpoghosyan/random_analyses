# %% [markdown]
# <a href="https://colab.research.google.com/github/azganushpoghosyan/fidap/blob/main/Onboarding_sample_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade fidap
# Out:
# ...
#      |████████████████████████████████| 122kB 9.7MB/s
# ...
#      |████████████████████████████████| 1.3MB 12.4MB/s
# ...
#      |████████████████████████████████| 143kB 32.0MB/s
# ...
#      |████████████████████████████████| 296kB 31.0MB/s
# ...

# %%
from fidap import fidap_client

# %%
fidap = fidap_client(api_key="e5bb3c8567d14dd28923d1cdbe0560a4")

# %%
df = fidap.sql(
"""
SELECT name, Median_Income_Person
FROM fidap-301014.datacommons.states
ORDER BY Median_Income_Person DESC
"""
)

# %%
display(df)
# Out:
#                     name  Median_Income_Person
# 0   District of Columbia                 49542
# 1               Maryland                 40341
# 2             New Jersey                 38238
# 3          Massachusetts                 37886
# 4            Connecticut                 37865
# 5              Minnesota                 36076
# 6             Washington                 35989
# 7               Colorado                 35887
# 8          New Hampshire                 35807
# 9                 Hawaii                 35515
# 10          North Dakota                 35499
# 11              Virginia                 35421
# 12                Alaska                 34018
# 13              Delaware                 33628
# 14              New York                 33562
# 15              Illinois                 32495
# 16          Rhode Island                 32256
# 17             Wisconsin                 32009
# 18               Wyoming                 31974
# ...
